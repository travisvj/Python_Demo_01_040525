# %% [markdown]
# <a href="https://colab.research.google.com/github/travisvj/Python_Demo_01_040525/blob/main/lesson13_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://www.perplexity.ai/search/b99dd1ac-2d40-4f7d-ba29-2972671abf18

# %%
import numpy as np

np.random.seed(5678)
scores = np.random.randint(50, 101, size=(50, 5))
scores
# Out:
# array([[ 73,  68,  63,  86,  64],
#        [ 81,  69,  64,  78,  80],
#        [ 65,  55,  68,  56,  50],
#        [ 55,  69,  76,  65,  59],
#        [ 69,  69,  75,  74,  53],
#        [ 75,  67,  92,  99,  71],
#        [ 54,  50,  84,  68,  62],
#        [ 63,  91,  52,  71,  78],
#        [ 68,  98,  70,  71,  96],
#        [ 82,  65,  82,  85,  63],
#        [ 98,  64, 100,  88,  61],
#        [ 58,  86,  84,  76,  70],
#        [ 69,  89,  94,  73,  67],
#        [ 91,  62,  83,  73,  76],
#        [ 79,  52,  87, 100,  65],
#        [ 96,  72,  88,  63,  65],
#        [ 65,  87,  69,  73,  74],
#        [ 63,  80,  84,  58,  88],
#        [ 51,  55,  88,  71,  97],
#        [ 97,  82,  90,  84,  59],
#        [ 52,  52,  71,  79,  82],
#        [ 81,  65,  68,  81,  87],
#        [ 93,  63,  68,  96,  87],
#        [ 57,  58,  50,  83,  99],
#        [ 55,  90,  67,  86,  69],
#        [ 73,  90,  54,  73,  60],
#        [ 79,  59,  63,  93,  51],
# ...

# %%
import pandas as pd

df = pd.DataFrame(scores,columns=["國文", "英文", "數學", "生物", "物理"],index=[f"學生{x}" for x in range(1,51)])
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
[x**2 for x in range(10) if x < 4]
# Out:
# [0, 1, 4, 9]

# %%
df.columns.name = "科目"
df.index.name = "姓名"
df
# Out:
# 科目     國文  英文   數學   生物  物理
# 姓名
# 學生1    73  68   63   86  64
# 學生2    81  69   64   78  80
# 學生3    65  55   68   56  50
# 學生4    55  69   76   65  59
# 學生5    69  69   75   74  53
# 學生6    75  67   92   99  71
# 學生7    54  50   84   68  62
# 學生8    63  91   52   71  78
# 學生9    68  98   70   71  96
# 學生10   82  65   82   85  63
# 學生11   98  64  100   88  61
# 學生12   58  86   84   76  70
# 學生13   69  89   94   73  67
# 學生14   91  62   83   73  76
# 學生15   79  52   87  100  65
# 學生16   96  72   88   63  65
# 學生17   65  87   69   73  74
# 學生18   63  80   84   58  88
# 學生19   51  55   88   71  97
# 學生20   97  82   90   84  59
# 學生21   52  52   71   79  82
# 學生22   81  65   68   81  87
# 學生23   93  63   68   96  87
# 學生24   57  58   50   83  99
# 學生25   55  90   67   86  69
# 學生26   73  90   54   73  60
# 學生27   79  59   63   93  51
# 學生28   92  91   67   79  92
# 學生29   60  82   96   96  62
# 學生30   80  63   74   96  51
# 學生31   51  92   72   86  52
# 學生32   71  95   88   54  94
# ...
